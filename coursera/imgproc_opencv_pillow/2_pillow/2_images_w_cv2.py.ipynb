# %%
import cv2
import matplotlib.pyplot as plt

# %%
IMG = '../../../img'
FIGSIZE = 5, 5

# %%
def concat_h(im1, im2):
    combined = Image.new('RGB', (im1.width + im2.width, im1.height))
    combined.paste(im1, (0, 0))
    combined.paste(im2, (im1.width, 0))
    return combined

# %%
img_path = f'{IMG}/baboon.png'
image = cv2.imread(img_path)
type(image), image.shape, image.min(), image.max()
# Out:
# (numpy.ndarray, (512, 512, 3), 0, 255)

# %%
plt.figure(figsize=FIGSIZE)
plt.imshow(image);

# %%
new_image=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(FIGSIZE))
plt.imshow(new_image);

# %%
image = cv2.imread(img_path)
image.shape
# cv2.imwrite('lenna.jpg', image)
# Out:
# (512, 512, 3)

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
image_gray.shape
# Out:
# (512, 512)

# %%
plt.figure(figsize=FIGSIZE)
plt.imshow(image_gray, cmap='gray');

# %%
# cv2.imwrite('lena_graycv.jpg', image_gray)

# %%
im_grey = cv2.imread(f'{IMG}/barbara.png', cv2.IMREAD_GRAYSCALE)
plt.figure(figsize=FIGSIZE)
plt.imshow(im_grey, cmap='gray');

# %%
baboon = cv2.imread(f'{IMG}/baboon.png')
plt.figure(figsize=FIGSIZE)
plt.imshow(cv2.cvtColor(baboon, cv2.COLOR_BGR2RGB));

# %%
blue, green, red = baboon[:, :, 0], baboon[:, :, 1], baboon[:, :, 2]

# %%
im_bgr = cv2.vconcat([blue, green, red])

# %%
plt.figure(figsize=FIGSIZE)
plt.subplot(121)
plt.imshow(cv2.cvtColor(baboon, cv2.COLOR_BGR2RGB))
plt.title('RGB')
plt.subplot(122)
plt.imshow(im_bgr,cmap='gray')
plt.title('Channels: (B, G, R)');

# %%
N_ROWS = 256
N_COLS = 128

# %%
plt.figure(figsize=FIGSIZE)
plt.imshow(new_image[:N_ROWS, :N_COLS, :]);

# %%
A = new_image.copy()
plt.imshow(A);

# %%
baboon_red = baboon.copy()
baboon_red[:, :, 0] = 0
baboon_red[:, :, 1] = 0
plt.figure(figsize=FIGSIZE)
plt.imshow(cv2.cvtColor(baboon_red, cv2.COLOR_BGR2RGB));

# %%
baboon_rg = baboon.copy()
baboon_rg[:, :, 0] = 0
plt.figure(figsize=FIGSIZE)
plt.imshow(cv2.cvtColor(baboon_rg, cv2.COLOR_BGR2RGB));
