# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
IMG = '../../../img'

# %%
image = cv2.imread(f'{IMG}/brain_MR.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
grey = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
plt.imshow(grey, cmap='gray');

# %% [markdown]
# ### Implement Canny edge detection

# %%
# Try Canny using "wide" and "tight" thresholds
wide = cv2.Canny(grey, 30, 100)
tight = cv2.Canny(grey, 200, 240)
 
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
ax1.set_title('wide')
ax1.imshow(wide, cmap='gray')
ax2.set_title('tight')
ax2.imshow(tight, cmap='gray');

# %% [markdown]
# ### TODO: Try to find the edges of this flower
#
# Set a small enough threshold to isolate the boundary of the flower.

# %%
image = cv2.imread(f'{IMG}/sunflower.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
grey = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
plt.imshow(grey, cmap='gray');

# %%
lower = 200
upper = 210
edges = cv2.Canny(grey, lower, upper)
plt.figure(figsize=(20, 10))
plt.imshow(edges, cmap='gray');
