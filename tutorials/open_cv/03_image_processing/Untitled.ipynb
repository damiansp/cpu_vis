# %%
#234567890#234567890#234567890#234567890#234567890#234567890#234567890#23456789
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
flags = [i for i in dir(cv) if i.startswith('COLOR_')]
#flags

# %%
# !ls ../../../img
# Out:
# baboon.png               flamingos.jpg            round_farms.jpg
# barbara.png              flower_photos            roundabout.jpeg
# bevpics                  FMNIST                   scrabble.jpeg
# birds.jpg                goldhill.bmp             shuttle.jpeg
# brain_MR.jpg             james.jpg                sobel_ops.png
# bridge_trees_example.jpg jeep1.jpeg               space_background.jpg
# cameraman.jpeg           jeep2.jpeg               stripes.jpg
# car.png                  jeep3.jpeg               sunflower.jpg
# cars.jpg                 lenna.png                Team.jpeg
# cat.jpeg                 mammogram.png            thumbs_up_down.jpg
# cat.png                  man.jpeg                 triangle_tile.jpeg
# city_hall_zoom.png       MNIST                    udacity_sdc.png
# city_hall.jpg            monarch.jpg              wa_state_highway.jpg
# curved_lane.jpg          multi_faces.jpg          waffle.jpg
# day_night                noisy_brain_MR.jpg       watch.jpeg
# diag_stripes.png         oranges_orig.jpg         water_balloons.jpg
# face.jpeg                pancakes.jpg             waymo_car.jpg
# faceQS.png               pedestrian_bike.jpeg     white_lines.jpg
# faceR.jpeg               phone.jpg                woman.jpeg
# faceRI.png               pink_solid.jpg           zelda.png
# faceRN5.png              pizza_bluescreen.jpg
# FashionMNIST             rainbow_flag.jpg

# %%
IMG = '../../../img'

# %%
img = cv.imread(f'{IMG}/baboon.png')
img = cv.cvtColor(img, cv.COLOR_RGB2BGR)
hsv = cv.cvtColor(img, cv.COLOR_RGB2HSV)
lower_blue = np.array([90, 50, 50])
upper_blue = np.array([150, 255, 255])
mask = cv.inRange(hsv, lower_blue, upper_blue)
res = cv.bitwise_and(img, img, mask=mask)
plt.imshow(img);

# %%
plt.imshow(mask);

# %%
plt.imshow(res);

# %%
green = np.uint8([[[0, 255, 0]]])
hsv_green = cv.cvtColor(green, cv.COLOR_BGR2HSV)
hsv_green
# Out:
# array([[[ 60, 255, 255]]], dtype=uint8)

# %%
# bound = [[H - 10, 100, 100], [H + 10, 255, 255]]
